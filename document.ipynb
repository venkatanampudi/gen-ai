# %% [markdown]
# ### COMPLETE GEN AI WITH LANGCHAIN & HUGGINGFACE
#
# ### Python programming
#
# ### NLP in Deep Learning:
# * RNN, LSTM, GRU, Bidirectional RNN, Encoder, Decoder, Attention Mechanism, Transformer, BERT --> This is the basic building blocks for LLM Models in Generative AI.
#
# ### Langchain Ecosystem ==> Generative AI Framework
# * Paid LLM models, Open source LLM models, Multimodal agents, Agents, chat with SQL databases, Vector Databases, Retrievers,
# Text summarization, chat message history
#
# ### Langchain packages
# * Langchain
# * Langchain core
# * Langchain community
# * Langchain tools
# * Streamlit packages
# ### Deployment techniques (Freee resources available in the market)
# ### Fine Tunining techniques (Google colab is free) and below are the fine tuning techniques:
# * Quantization
# * LoRA
# * QLoRA
# * Fine Tune with OpenSource LLM Models
#
# ### Gen AI in AWS using Bedrock service
# * Lambda Functions
# * API Gateway
# * SageMaker
#
# ### Nvidia NIM ==> End to End Project with LangChain
#
# ### Crew AI ==> Helps to create multi AI agents for Gen AI applications
#
# ### LLM and Multimodals use:
# 1. OpenAI
# 2. Google Gemma, Gemma2
# 3. Meta ==> Llama3
