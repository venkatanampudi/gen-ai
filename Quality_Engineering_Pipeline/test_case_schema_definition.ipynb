# %%
# Define test case schema
{
  "test_case_id": "string",
  "description": "string",
  "type": "functional | negative | edge",
  "steps": ["step1", "step2", "..."],
  "expected_result": "string"
}
